# %%
import sys
sys.path.append("../src")

import requests

from tonpy import LiteClient, Cell, get_block_info, BlockId, BlockIdExt, \
        Address, Emulator, begin_cell, StackEntry, VmDict, CellSlice

from tonpy.utils.shard_account import shard_is_ancestor, shard_child
from tonpy.libs.python_ton import Bits256
from tonpy.autogen.block import Account, Transaction, Block, BlockInfo, BlockExtra, MessageAny, AccountState

# Get random LiteServer
lc = LiteClient(mode='roundrobin', threads=1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       2 sys.path.append("../src")
#       4 import requests
# ----> 6 from tonpy import LiteClient, Cell, get_block_info, BlockId, BlockIdExt, \
#       7         Address, Emulator, begin_cell, StackEntry, VmDict, CellSlice
#       9 from tonpy.utils.shard_account import shard_is_ancestor, shard_child
#      10 from tonpy.libs.python_ton import Bits256
#
# File ~/projects/tonpy/src/tonpy/__init__.py:3
#       1 # Copyright (c) 2023 Disintar LLP Licensed under the Apache License Version 2.0
# ----> 3 from tonpy.types import *
#       4 from tonpy.tlb_gen import *
#       5 from tonpy.tvm import *
#
# File ~/projects/tonpy/src/tonpy/types/__init__.py:3
#       1 # Copyright (c) 2023 Disintar LLP Licensed under the Apache License Version 2.0
# ----> 3 from tonpy.types.cell import Cell
#       4 from tonpy.types.cellslice import CellSlice
#       5 from tonpy.types.cellbuilder import CellBuilder
#
# File ~/projects/tonpy/src/tonpy/types/cell.py:3
#       1 # Copyright (c) 2023 Disintar LLP Licensed under the Apache License Version 2.0
# ----> 3 from tonpy.libs.python_ton import PyCell, parse_string_to_cell, load_as_cell_slice
#       4 from typing import Union
#       6 from tonpy.types.cellslice import CellSlice
#
# ImportError: dlopen(/Users/tvorogme/projects/tonpy/src/tonpy/libs/python_ton.cpython-310-darwin.so, 0x0002): symbol not found in flat namespace '__ZN2td19TerminalIOOutputterD1Ev'
