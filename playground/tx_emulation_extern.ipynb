# %%
import sys
sys.path.append("../src")

import requests

from tonpy import LiteClient, Cell, get_block_info, BlockId, BlockIdExt, \
        Address, Emulator, begin_cell, StackEntry, VmDict, CellSlice

from tonpy.utils.shard_account import shard_is_ancestor, shard_child
from tonpy.libs.python_ton import Bits256
from tonpy.autogen.block import Account, Transaction, Block, BlockInfo, BlockExtra, MessageAny, AccountState

# %%
# Example hashes:
#   27 txs in 1 block: 184C0C0EF74E279E63B363FCC81168AEB4C3769E4991FAF6982A5E232EE88541
#   After merge: 7A074921055E014CE6B5E7C929B12D9789F5419E771F1BD98C379A57DA15064A
#   TickTock: F8EAC78DA7005B67B4A473CB77CF90ACD4A31B883E0E6C2806ADB4C0D2B3E616

# %%
tx_hash = "745BA37BA8E0C62371E04B815ABDE4DB8802272336708567FFD0D96A54418422"

# %%
def get_tx_lt(tx_hash):
    query = '''query{transactions(hash: "%s"){lt,address,workchain,shard}}''' % tx_hash

    response = requests.post("https://dton.io/graphql", json={'query': query})
    
    data = response.json()['data']['transactions'][0]
    return int(data['lt']), int(data['workchain']), str(data['address']), str(data['shard'])

# %%
# You can not trust this data from dton.io, but IF it's correct it'll be prooved by `get_transactions` later
tx_lt, wc, address, shard = get_tx_lt(tx_hash)
block_lt = tx_lt - tx_lt % 1000000

tx_account = Address(f"{wc}:{address}")

# %%
# Get random LiteServer
lc = LiteClient(mode='roundrobin', threads=1)

# When you get transaction - you automatically proof validness by tx_hash
transactions = lc.get_transactions(tx_account, tx_lt, tx_hash, 16).transactions

# We need to get all TXs in this block
whitelist_txs = [transactions[0]]
get_state_from = None
cur_index = 0

if len(transactions) > 1:
    done = transactions[0].blkid != transactions[1].blkid
else:
    done = True
    
while not done:
    cur_index += 1
    if cur_index > len(transactions) - 1:
        # Get new 16txs to load
        transactions.extend(lc.get_transactions(tx_account, 
                                          whitelist_txs[-1].prev_trans_lt, 
                                          whitelist_txs[-1].prev_trans_hash, 16).transactions)
    if cur_index > len(transactions):
        break
    
    if whitelist_txs[-1].blkid == transactions[cur_index].blkid:
        whitelist_txs.append(transactions[cur_index])
    else:
        done = True

# %%
# If there >1 TX in block - we need to emulate all of them before our one
print("To emulate, before our TX: ", len(whitelist_txs) - 1)

whitelist_txs = list(reversed(whitelist_txs))
# Out:
# To emulate, before our TX:  0

# %%
# Get block with prev state
# WARNING: this block is not proofed
state_block = whitelist_txs[0].blkid
current_block = lc.get_block_header(state_block)
print("Current block: ", current_block.blk_id, "\n")

# We need to get master block, so we can download libs and config
if wc != -1:
    # tlb python autogen
    block = Block().cell_unpack(current_block.virt_blk_root)
    block_info = BlockInfo().cell_unpack(block.info, True)
    
    # get master block id from WC
    master = BlockIdExt(id_=BlockId(-1, 0x8000000000000000, block_info.master_ref.master.seq_no), 
          file_hash=int(block_info.master_ref.master.file_hash, 2), 
          root_hash=int(block_info.master_ref.master.root_hash, 2))
else:
    master = current_block.blk_id

print("Master block: ", master, "\n")
# Out:
# Current block:  (-1,8000000000000000,36319299):6F3066DA91587118B68D24A8CEF170632AD6613F65B0E47D9B73E4098609C19B:F54013BADF6D0658A7472BE5B1908B546F71F60A9424E95EE794735ECBEFC38F
#
# Master block:  (-1,8000000000000000,36319299):6F3066DA91587118B68D24A8CEF170632AD6613F65B0E47D9B73E4098609C19B:F54013BADF6D0658A7472BE5B1908B546F71F60A9424E95EE794735ECBEFC38F

# %%
# Need to get rand_seed for block and get prev block with account state
current_full_block = lc.get_block(current_block.blk_id)

# It's stored in blockExtra
block = Block().cell_unpack(current_full_block)
block_info = BlockInfo().cell_unpack(block.info, True)
block_extra = BlockExtra().cell_unpack(block.extra, False)

rand_seed = int(block_extra.rand_seed, 2)

# %%
# To get prev block with account state - need to calculate correct shard (with account) if block is after merge
# If not after merge - just get prev seqno
if block_info.after_merge:    
    left = block_info.prev_ref.prev1
    left_shard = BlockIdExt(BlockId(wc, shard_child(current_block.blk_id.id.shard, True), left.seq_no),
                           root_hash=int(left.root_hash,2), file_hash=int(left.file_hash, 2))
    
    right = block_info.prev_ref.prev2
    right_shard = BlockIdExt(BlockId(wc, shard_child(current_block.blk_id.id.shard, False), right.seq_no),
                           root_hash=int(right.root_hash,2), file_hash=int(right.file_hash, 2))
    
    if shard_is_ancestor(left_shard.id.shard, tx_account.shard_prefix(60)):
        state_block = left_shard
    else:
        state_block = right_shard
else:
    current = block_info.prev_ref.prev
    state_block = BlockIdExt(BlockId(wc, current_block.blk_id.id.shard, current.seq_no),
                           root_hash=int(current.root_hash,2), file_hash=int(current.file_hash, 2))

# %%
print("State block: ", state_block, "\n")
# Out:
# State block:  (-1,8000000000000000,36319298):75887F59A905822745DBA438E59B6F47DDA0F1E5DEC3DB486867582E16C78EF2:D571A70FA71FDA1E1F24EB97781DD3077B9C61C6956C8A41DADB40EF0F4DE50B

# %%
# Load account state from prev block
account_state = lc.get_account_state(f"{wc}:{address}", state_block)

if not account_state.root.is_null():
    # Convert answer to AccountShardState
    account_state = begin_cell() \
        .store_ref(account_state.root) \
        .store_uint(int(account_state.last_trans_hash, 16), 256) \
        .store_uint(account_state.last_trans_lt, 64).end_cell()
else:
     account_state = begin_cell() \
        .store_ref(begin_cell().store_uint(0, 1).end_cell()) \
        .store_uint(int(account_state.last_trans_hash, 16), 256) \
        .store_uint(account_state.last_trans_lt, 64) \
        .end_cell()

# %%
# Load config of prev key block of MC block where TX was
# WARNING: this key block have no proof
key_block, config = lc.get_config_all(master, from_not_trusted_keyblock=True)

# %%
print("Latest key block: ", key_block)
# Out:
# Latest key block:  (-1,8000000000000000,36317813):E3A91013932F2A5CD00912831E818007FBB72216F70070B600D5B890A0E502A4:02391552B7D91167FDFBF3E4F26D26FB7A320173A9B2EFEEE3FD9AC2B74352BF

# %%
# for emulation you need to get 16 latest mc blocks + 1 key block
old_mc_blocks = []
cur_seqno = master.id.seqno

for i in range(16):
    cur_seqno -= 1
    old_mc_blocks.append(lc.lookup_block(BlockId(-1, 0x8000000000000000, cur_seqno)).blk_id)

# %%
prev_block_data = [
    [i.to_data() for i in old_mc_blocks],
    key_block.to_data()
]

# %%
# Here we need to get all public libraries (todo: rewrite on new LS API if it'll be published)
# Alternative: deep_library_search 
def get_public_libs(block_hash, wc, seqno, shard):
    query = '''query{blocks(workchain: %s, seqno: %s, shard: %s, root_hash: "%s"){libs_hash}}''' % (wc, seqno, shard, block_hash)

    response = requests.post("https://dton.io/graphql", json={'query': query})
    
    data = response.json()['data']['blocks'][0]
    return data['libs_hash']

# %%
public_libs = get_public_libs(master.root_hash, master.id.workchain, master.id.seqno, master.id.shard)

print("Found: ", len(public_libs), " public libs")

libs_data = lc.get_libraries(public_libs)
# Out:
# Found:  40  public libs

# %%
account_state.get_hash()
# Out:
# 'E999765C75C228B6A87A944A5060A3BD60C06B67A4572C8BD5C0D17DCEC00F62'

# %%
gg = lc.list_block_transactions_ext(master, 1)

# %%
for i in gg.transactions:
    tt = Transaction().cell_unpack(i)
    print(i.get_hash(), tt.dump()['account_addr'], tt.dump()['lt'])
# Out:
# 745BA37BA8E0C62371E04B815ABDE4DB8802272336708567FFD0D96A54418422 3333333333333333333333333333333333333333333333333333333333333333 44856566000001

# %% [markdown]
# # External emulator

# %%
from tonpy.tvm.not_native.emulator_extern import EmulatorExtern

# %%
em = EmulatorExtern("/Users/tvorogme/projects/ton_original/build/emulator/libemulator.dylib", config)

em.set_rand_seed(rand_seed)
em.set_prev_blocks_info(prev_block_data)
em.set_libs(libs_data)
# Out:
# True

# %%
for tx in whitelist_txs:
    # Get current transaction LT & now
    current_tx = tx.transaction

    tx_tlb = Transaction()
    tx_tlb = tx_tlb.cell_unpack(current_tx, True)

    lt = tx_tlb.lt
    now = tx_tlb.now
    
    # Get current trasaction in_msg
    current_tx_cs = current_tx.begin_parse()
    tmp = current_tx_cs.load_ref(as_cs=True)

    if tmp.load_bool():
        in_msg = tmp.load_ref()
    else:
        # TICK TOCK
        in_msg = None

    if in_msg is None:
        success = em.emulate_tick_tock_transaction(
                    account_state,
                    tx_tlb.description.is_tock,
                    now,
                    lt
                )
    else:
        # Emulate
        success = em.emulate_transaction(
            account_state,
            in_msg,
            now,
            lt
        )
        
    assert success
    
    # Emulation transaction equal current transaction
    assert em.transaction.get_hash() == current_tx.get_hash()
    print(f"Emulate {current_tx.get_hash()} success")
    
    # Update account state, go to next transaction
    account_state = em.account.to_cell()
# Out:
# Emulate 745BA37BA8E0C62371E04B815ABDE4DB8802272336708567FFD0D96A54418422 success

# %%
c = Cell('...')
# Out:
# [ 1][t 1][1708956733.489479065][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956733.496727228][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956734.499046087][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956735.593051910][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956736.504400969][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956737.502191305][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956738.506991148][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956739.509668112][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956740.507309198][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956741.513125896][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956742.514655113][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956743.515846014][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956744.519741058][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956745.514702082][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956746.517588139][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956747.518362999][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956748.522337198][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956749.525260210][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956750.525861979][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956751.531637192][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956752.532324314][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956753.529739141][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956754.529765129][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956755.532844067][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956756.534229040][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956757.533551216][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956758.534711123][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956759.540133953][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956760.540854216][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956761.538633108][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956762.543170214][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956763.542387962][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956764.545330048][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956765.547775030][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956766.553723097][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956767.549837112][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956768.552642107][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956769.552837133][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956770.555110931][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956771.555994987][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956772.557892084][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956773.563928127][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956774.563395262][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956775.562458277][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956776.566916227][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956777.566232204][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956778.569354057][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956779.569819927][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956780.572978020][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956781.569999933][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956782.594212294][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956783.575401068][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956784.581948042][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956785.579486132][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956786.581647158][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956787.579687119][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956788.583954096][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956789.585586071][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956790.598133087][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956791.584969044][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956792.586219072][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956793.588279247][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956794.590403080][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956795.591366053][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956796.593881130][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956797.601905107][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956798.605572224][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956799.604906082][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956800.606812954][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956801.609955072][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956802.613078117][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956803.613359213][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956804.614338160][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956805.615450144][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956806.619579077][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956807.622240067][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956808.639593124][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956809.626358032][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956810.627682209][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956811.627419949][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956812.633237123][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956813.635174036][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956814.639086246][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956815.640118122][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956816.647963047][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956817.644229889][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956818.645002127][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956819.647589207][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956820.648838997][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956821.650422096][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956822.650723219][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956823.650575161][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956824.654864073][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956825.655212164][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956826.656026125][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956827.657230139][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956828.659968138][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956829.659763098][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956830.659577131][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956831.663350105][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956832.666719198][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956833.668941259][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956834.668647051][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956835.669224977][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956836.671035051][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956837.673503160][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956838.674894094][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956839.680346966][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956840.677508116][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956841.682975054][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956842.683103085][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956843.687053204][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956844.687779188][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956845.688796997][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956846.692508936][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956847.691489220][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956848.700779200][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956849.696712017][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956850.698126078][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956851.700416088][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956852.702416897][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956853.702658176][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956854.705990076][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956855.705353975][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956856.706585169][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956857.708854198][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956858.710793972][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956859.711729050][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956860.715721130][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956861.714678049][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956862.718231201][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956863.718905210][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956864.719927073][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956865.721652985][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956866.727459192][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956867.726855040][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956868.734560013][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956869.731270075][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956870.729537249][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956871.732759237][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956872.733533144][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956873.735063076][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956874.736653090][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956875.736951113][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956876.740542173][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956877.742702246][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956878.748160124][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956879.744452238][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956880.748091936][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956881.749167204][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956882.750208139][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956883.760184288][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956884.755129099][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956885.755002260][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956886.755751133][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956887.757891178][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956888.760768175][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956889.763994217][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956890.764384031][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956891.767472267][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956892.767218113][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956893.772776127][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956894.771770239][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956895.773072004][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956896.775782108][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956897.776344061][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956898.777221918][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956899.780318022][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956900.785978317][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956901.780973196][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956902.784733057][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956903.786726952][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956904.788816929][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956905.790534019][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956906.790993929][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956907.792293310][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956908.798928022][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956909.796394110][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956910.800494194][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956911.797836065][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956912.798192978][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956913.800983191][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956914.800201178][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956915.801812172][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956916.803029060][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956917.807210207][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956918.806947231][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956919.832874060][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956920.807307005][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956921.809458971][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956922.810615063][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956923.812835217][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956924.819031239][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956925.818268061][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956926.821370125][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956927.823552132][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956928.823442936][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956929.825179100][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956930.824240923][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956931.830721140][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956932.828587055][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956933.832862139][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956934.829409122][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956935.835746050][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956936.837259054][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956937.837710142][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956938.836796045][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956939.840860128][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956940.841886044][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956941.848286152][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956942.857878208][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956943.852441311][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956944.848477125][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956945.851266146][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956946.852244139][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956947.852032185][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956948.855082035][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956949.859890938][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956950.864739180][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956951.864017010][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956952.867506027][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956953.870404243][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956954.872721910][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956955.872741938][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956956.872394085][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956957.874176025][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956958.875669003][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956959.876851082][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956960.880361080][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956961.882427931][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956962.883572102][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956963.884843111][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956964.887923956][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956965.888394117][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956966.889859200][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956967.892254114][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956968.892737150][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956969.896199942][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956970.897553921][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956971.897530317][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956972.901539087][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956973.902808189][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956974.904645205][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956975.904453993][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956976.906679153][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956977.906867027][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956978.907120228][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956979.910001993][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956980.910963058][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956981.911470175][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956982.920205116][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956983.914885998][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956984.923103094][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956985.918548107][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956986.918956041][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956987.924069881][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956988.920385122][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956989.922594070][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956990.922621965][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956991.927600145][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956992.926549196][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956993.927794933][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956994.930727959][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956995.936149120][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956996.940420151][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956997.937566996][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956998.937699080][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708956999.938551188][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957000.940620184][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957001.951487064][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957002.945140123][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957003.947775126][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957004.948772192][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957005.949501038][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957006.951961279][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957007.953997135][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957008.955787182][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957009.960574150][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957010.965082884][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957011.966297150][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957012.967432022][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957013.969707012][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957014.970799208][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957015.972398281][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957016.978367090][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957017.978957176][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957018.977379084][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957019.983237267][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957020.984473228][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957021.982879162][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957022.986435175][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708957023.985156298][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# ...
# [ 1][t 1][1708964756.907009125][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964757.909300089][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964758.910568953][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964759.911396265][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964760.916796923][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964761.915369987][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964762.913434267][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964763.920531034][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964764.932161093][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964765.923357964][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964766.921317339][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964767.927777052][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964768.926573277][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964769.928685188][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964770.931350231][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964771.933136940][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964772.937367201][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964773.945386171][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964774.950911045][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964775.949562311][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964776.951027155][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964777.948913097][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964778.949018240][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964779.953633070][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964780.957866192][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964781.955178022][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964782.956768036][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964783.959453106][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964784.959543228][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964785.973424911][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964786.970607281][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964787.971027136][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964788.975855112][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964789.977512121][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964790.983880997][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964791.987689018][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964792.982640266][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964793.984724998][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964794.991884232][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964795.995445013][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964796.991173267][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964797.995967150][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964799.004841089][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964799.996494293][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964800.999149084][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964801.998332977][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964803.000831127][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964804.008258104][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964805.008864164][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964806.011588097][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964807.012791157][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964808.013534069][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964809.015344143][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964810.036474943][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964820.032721043][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964821.035141945][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964822.048986197][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964823.037407160][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964824.040579081][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964825.039107084][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964826.046797276][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964827.043421030][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964828.050458193][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964829.050524950][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964830.048660994][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964831.054117918][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964832.053045034][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964833.059238911][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964834.059800148][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964835.070231199][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964836.154733181][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964837.066744089][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964838.068786144][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964839.074078083][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964840.071551085][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964841.073723078][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964842.074393272][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964843.076569080][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964844.078480959][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964845.080358028][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964846.087218046][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964847.086495161][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964848.087443113][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964849.092971087][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964850.090769053][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964851.092613935][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964852.093904972][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964853.097233057][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964854.097816229][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964855.098563194][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964856.102565289][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964857.102277279][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964858.111364126][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964859.105854034][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964860.108588219][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964861.108164310][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]
# [ 1][t 1][1708964862.119899988][adnl-ext-connection.cpp:129][!outconn]	Client got error [PosixError : Connection reset by peer : 54 : Read from [fd:81] has failed]

# %%
c.get_hash()

# %%
c.dump_as_tlb("Transaction")
