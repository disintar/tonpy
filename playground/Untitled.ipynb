# %%
from tonpy.fift import Fift
from tonpy import Cell

code = "..."
Cell(code).get_hash()

a = Fift(silent=False)
a.add_lib("Disasm.fif")
    
a.run(f"""
"{code}" base64>B B>boc <s std-disasm disasm 
""")

for i in a.get_stack():
    print(i.get())
# Out:
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
#  ok
# ...
