# %%
test_data = {'tx_num': 11, 'state': 'te6ccuEBAgEALgBWXAFQUak2Vnb4GBN1uAWPNMVLUqXqRioHkksAYOheMBMLlEEAACZSIfbb2gEAAUDs8PSy', 'message': 'te6ccuEBAQEAZwDOAMlIAZFrItyZZ/7briT3vcJJVdiiAuCp8WqVmFG3fOGqEN9FAB6qx22ri5FbXgUHoirdb0Msjpp1nmtkSg2nMr1qxcq4EOFGWKgGFFhgAABMpEPtt6LKf9TUapk7bYAAAAAAAAAAQDKbo7o=', 'now': 1698687594, 'lt': 42134199000027, 'is_tock': False, 'rand_seed': '0000000000000000000000000000000000010000000000000000000000000000', 'config_root': '...', 'em_hash': '44C08EB9E06755BEE199443BC1884C61BA4FD86EF2EF30AB24462942A9950710'}

# %%
from tonpy import *
from tonpy import Emulator, Cell, VmDict

# %%
acc = CellSlice(test_data['state'])

# %%
hex(acc.load_uint(256)).upper()[2:], acc.load_uint(64)
# Out:
# ('51A9365676F8181375B8058F34C54B52A5EA462A07924B0060E85E30130B9441',
#  42134199000026)

# %%
libs = '...'


em = Emulator(VmDict(key_len=32, signed=False, cell_root=Cell(test_data['config_root'])))
em.set_rand_seed(test_data['rand_seed'])
em.set_libs(VmDict(key_len=256, signed=False, cell_root=Cell(libs)))
success = em.emulate_transaction(
    Cell(test_data['state']),
    Cell(test_data['message']),
    int(test_data['now']),
    int(test_data['lt']),
    True
)
assert success
print(em.transaction.get_hash())
# Out:
# FFB955C435DB46B5848D913F5B31E487B9D83C52611FC05D8D4AC7AFFF28CD45
# [ 1][t 0][1701154126.139056921][PyEmulator.cpp:126]	HERE!

# %%
print(em.transaction.dump_as_tlb("Transaction"))
# Out:
# (transaction account_addr:x7AAB1DB6AE2E456D78141E88AB75BD0CB23A69D679AD9128369CCAF5AB172AE0 lt:42134199000027 prev_trans_hash:x51A9365676F8181375B8058F34C54B52A5EA462A07924B0060E85E30130B9441 prev_trans_lt:42134199000026 now:1698687594 outmsg_cnt:0
#   orig_status:acc_state_uninit
#   end_status:acc_state_uninit
#   (
#     in_msg:(just
#       value:^(message
#         info:(int_msg_info ihr_disabled:1 bounce:0 bounced:0
#           src:(addr_std
#             anycast:nothing workchain_id:0 address:xC8B5916E4CB3FF6DD7127BDEE124AAEC51017054F8B54ACC28DBBE70D5086FA2)
#           dest:(addr_std
#             anycast:nothing workchain_id:0 address:x7AAB1DB6AE2E456D78141E88AB75BD0CB23A69D679AD9128369CCAF5AB172AE0)
#           value:(currencies
#             grams:(nanograms
#               amount:(var_uint len:4 value:944870954))
#             other:(extra_currencies
#               dict:hme_empty))
#           ihr_fee:(nanograms
#             amount:(var_uint len:0 value:0))
# ...
